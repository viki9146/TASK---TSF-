# %% [markdown]
# # Computer Vision & IoT Internship @ The Sparks Foundation

# %% [markdown]
# ### Author = Vivek Vilas Deshmukh

# %% [markdown]
# ## Task 1: Optical Character Recognition (OCR)¶

# %% [markdown]
# # Importing Library

# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np
from IPython.display import display, Image

# %% [markdown]
# # Ocr On Single Word

# %%
#Image 1 before OCR
image_path= 'invinncible.jpg'
im1 = cv2.imread('invinncible.jpg')
plt.imshow(im1)
plt.show()

# %%
reader = easyocr.Reader(['en'],gpu=False)
result = reader.readtext(image_path)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# C:\Users\Lenovo\anaconda3\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# [([[76, 86], [312, 86], [312, 150], [76, 150]],
#   'INVINCIBLE',
#   0.9950317466302078)]

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.LINE_AA

# %%
#Image 1 after OCR
img = cv2.imread(image_path)
img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),10)
img = cv2.putText(img,text,top_left, font, 2,(225,0,0),2,cv2.LINE_AA)
plt.figure(figsize=(7,7))
plt.imshow(img)
plt.show()

# %% [markdown]
# # ocr on multiple words

# %%
#Image 2 before OCR
image_path2='start.jpg'
im2 = cv2.imread('start.jpg')
plt.imshow(im2)
plt.show()

# %%
reader = easyocr.Reader(['en'],gpu=False)
result = reader.readtext(image_path2)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[32, 106], [264, 106], [264, 154], [32, 154]],
#   'STARTING',
#   0.9999738688125019),
#  ([[112, 146], [264, 146], [264, 194], [112, 194]],
#   'POINT',
#   0.9999132075950031)]

# %%
#Image 2 after OCR
img = cv2.imread(image_path2)
for detection in result: 
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),5)
    img = cv2.putText(img,text,top_left, font, 2,(225,0,0),2,cv2.LINE_AA)

plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()

# %% [markdown]
# # ocr on multiple lines

# %%
#Image 3 before OCR
image_path3='thougt.jpg'
im3 = cv2.imread('thougt.jpg')
plt.imshow(im3)
plt.show()

# %%
reader = easyocr.Reader(['en'],gpu=False)
result = reader.readtext(image_path3)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[63, 75], [267, 75], [267, 117], [63, 117]], '3HOUGH', 0.23911542248534073),
#  ([[118, 122], [228, 122], [228, 152], [118, 152]],
#   'OR EHEE',
#   0.16142687913584303),
#  ([[165, 155], [285, 155], [285, 197], [165, 197]],
#   'WEEKI',
#   0.39258721346182734)]

# %%
#Image 3 after OCR
img = cv2.imread(image_path3)
for detection in result: 
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img,top_left,bottom_right,(102,255,102),2)
    img = cv2.putText(img,text,top_left, font, 0.8,(204,0,0),3,cv2.LINE_AA)

plt.figure(figsize=(15,15))
plt.imshow(img)
plt.show()

# %%
#Image 4 before OCR
image_path4='army.jpg'
im4 = cv2.imread('army.jpg')
plt.imshow(im4)
plt.show()

# %%
reader = easyocr.Reader(['en'],gpu=False)
result = reader.readtext(image_path4)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[73, 235], [279, 235], [279, 270], [73, 270]],
#   'INDIAN ARMY',
#   0.9991871482687491)]

# %%
#Image 4 after OCR 
img = cv2.imread(image_path4)
for detection in result: 
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img,top_left,bottom_right,(102,255,102),2)
    img = cv2.putText(img,text,top_left, font, 0.8,(255,0,127),2,cv2.LINE_AA)

plt.figure(figsize=(15,15))
plt.imshow(img)
plt.show()

# %% [markdown]
# # ocr on handwritten words

# %%
#Image 7 before OCR
image_path7='WIN_20210811_18_41_10_Pro.jpg'
im7 = cv2.imread('WIN_20210811_18_41_10_Pro.jpg')
plt.imshow(im7)
plt.show()

# %%
reader = easyocr.Reader(['en'],gpu=False)
result = reader.readtext(image_path7)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[669.9901749867297, 366.1125573818941],
#    [920.4080377035566, 337.210725254546],
#    [927.0098250132703, 490.8874426181059],
#    [676.5919622964434, 519.789274745454]],
#   'Vivek',
#   0.8538404621839035)]

# %%
#Image 7 after OCR
img = cv2.imread(image_path7)
for detection in result: 
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,1),5)
    img = cv2.putText(img,text,top_left, font,5,(255,0,0),7,cv2.LINE_AA)

plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()

# %% [markdown]
# # Thank You
